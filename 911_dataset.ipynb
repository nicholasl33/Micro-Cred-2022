# %% [markdown]
# <a href="https://colab.research.google.com/github/nicholasl33/Micro-Cred-2022/blob/main/911_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
import plotly
import cufflinks as cf

# %%
df = pd.read_csv('https://raw.githubusercontent.com/glopez21/ML-Data/main/911.csv')

# %%
df.shape
# Out:
# (99492, 9)

# %%
df.head()
# Out:
#          lat        lng  ...                        addr  e
# 0  40.297876 -75.581294  ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                    HAWS AVE  1
# 3  40.116153 -75.343513  ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350  ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
df.dropna()
# Out:
#              lat        lng  ...                            addr  e
# 0      40.297876 -75.581294  ...          REINDEER CT & DEAD END  1
# 1      40.258061 -75.264680  ...      BRIAR PATH & WHITEMARSH LN  1
# 2      40.121182 -75.351975  ...                        HAWS AVE  1
# 3      40.116153 -75.343513  ...              AIRY ST & SWEDE ST  1
# 5      40.253473 -75.283245  ...           CANNON AVE & W 9TH ST  1
# ...          ...        ...  ...                             ... ..
# 99487  40.132869 -75.333515  ...         MARKLEY ST & W LOGAN ST  1
# 99488  40.006974 -75.289080  ...  LANCASTER AVE & RITTENHOUSE PL  1
# 99489  40.115429 -75.334679  ...         CHESTNUT ST & WALNUT ST  1
# 99490  40.186431 -75.192555  ...           WELSH RD & WEBSTER LN  1
# 99491  40.207055 -75.317952  ...          MORRIS RD & S BROAD ST  1
#
# [86576 rows x 9 columns]

# %%
df.head(20000)

# %% [markdown]
# Question to ask:
#
# What are the most common EMS calls?
#
# What are the most common non-EMS calls?
#
# Which zip code appears to have the most 911 calls?

# %% [markdown]
# # In which townships should we prioritize placing traffic police? (Which townships have a higher likelihood of having a vehicle accident)

# %%
df.head()
# Out:
#          lat        lng  ...                        addr  e
# 0  40.297876 -75.581294  ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                    HAWS AVE  1
# 3  40.116153 -75.343513  ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350  ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
df.drop(['lat', 'lng', 'timeStamp', 'addr'], axis=1, inplace=True)

# %%
df.head()
# Out:
#                                                 desc  ...  e
# 0  REINDEER CT & DEAD END;  NEW HANOVER; Station ...  ...  1
# 1  BRIAR PATH & WHITEMARSH LN;  HATFIELD TOWNSHIP...  ...  1
# 2  HAWS AVE; NORRISTOWN; 2015-12-10 @ 14:39:21-St...  ...  1
# 3  AIRY ST & SWEDE ST;  NORRISTOWN; Station 308A;...  ...  1
# 4  CHERRYWOOD CT & DEAD END;  LOWER POTTSGROVE; S...  ...  1
#
# [5 rows x 5 columns]

# %%
df.loc[df['title'] == 'Traffic: VEHICLE ACCIDENT -']
# Out:
#                                                     desc  ...  e
# 9      BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  ...  1
# 10     RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...  ...  1
# 11     BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  ...  1
# 12     BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  ...  1
# 13     OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  ...  1
# ...                                                  ...  ... ..
# 99478  CHEMICAL RD & GALLAGHER RD; PLYMOUTH; 2016-08-...  ...  1
# 99486  WELSH RD & NORRISTOWN RD; HORSHAM; 2016-08-24 ...  ...  1
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  ...  1
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  ...  1
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  ...  1
#
# [23066 rows x 5 columns]

# %%
df_2 = df.loc[df['title'] == 'Traffic: VEHICLE ACCIDENT -']

# %%
df_2.head()
# Out:
#                                                  desc  ...  e
# 9   BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  ...  1
# 10  RT202 PKWY & KNAPP RD; MONTGOMERY; 2015-12-10 ...  ...  1
# 11  BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  ...  1
# 12  BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  ...  1
# 13  OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  ...  1
#
# [5 rows x 5 columns]

# %%
df_2.dropna()
# Out:
#                                                     desc  ...  e
# 9      BLUEROUTE  & RAMP I476 NB TO CHEMICAL RD; PLYM...  ...  1
# 11     BROOK RD & COLWELL LN; PLYMOUTH; 2015-12-10 @ ...  ...  1
# 12     BYBERRY AVE & S WARMINSTER RD; UPPER MORELAND;...  ...  1
# 13     OLD YORK RD & VALLEY RD; CHELTENHAM; 2015-12-1...  ...  1
# 15     STUMP RD & WITCHWOOD DR; MONTGOMERY; 2015-12-1...  ...  1
# ...                                                  ...  ... ..
# 99478  CHEMICAL RD & GALLAGHER RD; PLYMOUTH; 2016-08-...  ...  1
# 99486  WELSH RD & NORRISTOWN RD; HORSHAM; 2016-08-24 ...  ...  1
# 99487  MARKLEY ST & W LOGAN ST; NORRISTOWN; 2016-08-2...  ...  1
# 99488  LANCASTER AVE & RITTENHOUSE PL; LOWER MERION; ...  ...  1
# 99491  MORRIS RD & S BROAD ST; UPPER GWYNEDD; 2016-08...  ...  1
#
# [19536 rows x 5 columns]

# %% [markdown]
# # gengis way

# %%
call = pd.read_csv('https://raw.githubusercontent.com/glopez21/ML-Data/main/911.csv')

# %%
call.head()
# Out:
#          lat        lng  ...                        addr  e
# 0  40.297876 -75.581294  ...      REINDEER CT & DEAD END  1
# 1  40.258061 -75.264680  ...  BRIAR PATH & WHITEMARSH LN  1
# 2  40.121182 -75.351975  ...                    HAWS AVE  1
# 3  40.116153 -75.343513  ...          AIRY ST & SWEDE ST  1
# 4  40.251492 -75.603350  ...    CHERRYWOOD CT & DEAD END  1
#
# [5 rows x 9 columns]

# %%
call.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 99492 entries, 0 to 99491
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   lat        99492 non-null  float64
#  1   lng        99492 non-null  float64
#  2   desc       99492 non-null  object
#  3   zip        86637 non-null  float64
#  4   title      99492 non-null  object
#  5   timeStamp  99492 non-null  object
#  6   twp        99449 non-null  object
#  7   addr       98973 non-null  object
#  8   e          99492 non-null  int64
# dtypes: float64(3), int64(1), object(5)
# memory usage: 6.8+ MB

# %%
call.describe()
# Out:
#                 lat           lng           zip        e
# count  99492.000000  99492.000000  86637.000000  99492.0
# mean      40.159526    -75.317464  19237.658298      1.0
# std        0.094446      0.174826    345.344914      0.0
# min       30.333596    -95.595595  17752.000000      1.0
# 25%       40.100423    -75.392104  19038.000000      1.0
# 50%       40.145223    -75.304667  19401.000000      1.0
# 75%       40.229008    -75.212513  19446.000000      1.0
# max       41.167156    -74.995041  77316.000000      1.0

# %% [markdown]
# # What are the top 5 zip codes for 911 calls?

# %%
call['zip']
# Out:
# 0        19525.0
# 1        19446.0
# 2        19401.0
# 3        19401.0
# 4            NaN
#           ...
# 99487    19401.0
# 99488    19003.0
# 99489    19401.0
# 99490    19002.0
# 99491    19446.0
# Name: zip, Length: 99492, dtype: float64

# %%
call['zip'].value_counts().head()
# Out:
# 19401.0    6979
# 19464.0    6643
# 19403.0    4854
# 19446.0    4748
# 19406.0    3174
# Name: zip, dtype: int64

# %% [markdown]
# # What are top 5 townships for 911 calls?

# %%
call['twp'].value_counts().head()
# Out:
# LOWER MERION    8443
# ABINGTON        5977
# NORRISTOWN      5890
# UPPER MERION    5227
# CHELTENHAM      4575
# Name: twp, dtype: int64

# %%
call['title'].value_counts()
# Out:
# Traffic: VEHICLE ACCIDENT -        23066
# Traffic: DISABLED VEHICLE -         7702
# Fire: FIRE ALARM                    5496
# EMS: RESPIRATORY EMERGENCY          5112
# EMS: CARDIAC EMERGENCY              5012
#                                    ...
# EMS: DISABLED VEHICLE                  1
# Fire: DIABETIC EMERGENCY               1
# Fire: UNKNOWN MEDICAL EMERGENCY        1
# Fire: SYNCOPAL EPISODE                 1
# Fire: UNCONSCIOUS SUBJECT              1
# Name: title, Length: 110, dtype: int64

# %% [markdown]
# # I would like to create new features

# %%
string = "This:string"

# %%
string.split(':')[0]
# Out:
# 'This'

# %%
call['Reason'] = call['title'].apply(lambda title: title.split(':')[0]) #lambda title == def title():

# %%
call.head()
# Out:
#          lat        lng  ...  e  Reason
# 0  40.297876 -75.581294  ...  1     EMS
# 1  40.258061 -75.264680  ...  1     EMS
# 2  40.121182 -75.351975  ...  1    Fire
# 3  40.116153 -75.343513  ...  1     EMS
# 4  40.251492 -75.603350  ...  1     EMS
#
# [5 rows x 10 columns]

# %%
call['Reason'].value_counts()
# Out:
# EMS        48877
# Traffic    35695
# Fire       14920
# Name: Reason, dtype: int64

# %% [markdown]
# # Using sns to create a countplot of 911 calls by reason

# %%
sns.countplot(x='Reason', data=call, order = call['Reason'].value_counts().index)

# how can we sort the order of the plots within the plot itself?
